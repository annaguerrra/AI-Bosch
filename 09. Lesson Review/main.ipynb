# %% [markdown]
# # Regressão Simples
#
# P = b + m * v
#
# **Característica:**
# Única variável exploratória
#
# **Hiperparâmetro:**
# Nenhum
#
# **Código:**
# regressor = LinearRegression()
# regressor.fit(x_train, y_train)
# prev = regressor.predict(x_test)
#
# **Métrica de Erro:**
# MAE -> Mean Absolute Error
#
# **Métrica de Desempenho:**
# regressor.score(x_test, y_test)
# regressor.score(x_train, y_train)

# %% [markdown]
# # Múltipla
# fórmula:
# P = b + m1* v1 + m2 * v2 + ...
#
# Característica
# Duas ou mais variáveis exploratórias
# Hiperparâmetro
# Nenhum
#
# Código
#
#
# Métrica de Erro
# MAE
#
# Métrica de Desempenho

# %% [markdown]
# Polinomial
# P = C + m1 * v1  + m2 * v2 ...
#
# Utilizamos quando a relação com o target não é linear, ou seja, curva
#
# Hiperparâmetro
# Degree (grau de polinômio)
#
# Código
# from sklearn.preprocessing import PolynomialFeatures
# poly = Poly
# x_train = poly.fit_transform(x_train)

# %% [markdown]
# # Elastic Net
# Algortimo regularizador, reduz o overfitting. Usa Ridge para controlar exageros e usa Lasso par eliminar variáveis inúteis. Requer Standard Scaler
#
# Hiperparâmetro: Alpha (força de regularização)
# l1_ratio 0 a 1 (Equilíbrio entre Lasso e Ridge)
#
# Código
# MAE

# %% [markdown]
# # Naive Bayes

# %% [markdown]
# # KNN (K-Neighbors-Nearest)

# %% [markdown]
# # Regressão Logística

# %% [markdown]
# Utiliza função sigmoid para encontrar a melhor linha e encaixar os dados
#
# Hiperparâmtro
# max_iter
#
# Métrica de erro Matriz de Confusão
# Métrica de desempenho: accuracy_score

# %% [markdown]
# # SVM

# %% [markdown]
# # Anova

# %% [markdown]
# # Label Encoding
